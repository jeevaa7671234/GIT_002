# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"e:\All about DS\DS\questions\SVM\SVM_classifier (1)\letterdata.csv")

# %%
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8    3.0       5      1   8.0    13      0    6.0
# 1          I     5    12    3.0       7      2  10.0     5      5    4.0
# 2          D     4    11    6.0       8      6  10.0     6      2    6.0
# 3          N     7    11    6.0       6      3   5.0     9      4    6.0
# 4          G     2     1    3.0       1      1   8.0     6      6    6.0
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2    3.0       3      2   7.0     7      7    6.0
# 19996      C     7    10    8.0       8      4   4.0     8      6    9.0
# 19997      T     6     9    6.0       7      5   6.0    11      3    7.0
# 19998      S     2     3    4.0       2      1   8.0     7      2    6.0
# 19999      A     4     9    6.0       6      2   9.0     5      3    1.0
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...
